# %% [markdown]
# ### Student Data Analysis

# %%
# %pip install seaborn

# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")
print(pd.__version__)
# Out:
# 1.5.3

# %%
df = pd.read_csv("Data analyst Data.csv")
df.head(5)
# Out:
#         Name           Email ID  Quantity                  Events  \
# 0     ANIKET     aniket@xyz.com         1  Art of Resume Building
# 1  Dhanshree  dhanshree@xyz.com         1  Art of Resume Building
# 2     Dhiraj     dhiraj@xyz.com         1  Art of Resume Building
# 3      Pooja      pooja@xyz.com         1  Art of Resume Building
# 4     Aayush     aayush@xyz.com         1  Art of Resume Building
#
#   Attendee Status                                       College Name  \
# 0       Attending  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1       Attending                   AP SHAH INSTITUTE OF TECHNOLOGY
# 2       Attending       Don Bosco College of Engineering Fatorda Goa
# 3       Attending           Pillai College of Engineering New Panvel
# 4       Attending                               St Xavier's College
#
#         How did you come to know about this event?  \
# 0                                            Email
# ...

# %%
df.shape

df.describe()
# Out:
#        Quantity  Year of Graduation         CGPA  \
# count    4894.0         4894.000000  4894.000000
# mean        1.0         2024.176951     8.038476
# std         0.0            1.000180     1.005184
# min         1.0         2023.000000     6.200000
# 25%         1.0         2023.000000     7.200000
# 50%         1.0         2024.000000     7.900000
# 75%         1.0         2025.000000     8.900000
# max         1.0         2026.000000     9.900000
#
#        Experience with python (Months)  Expected salary (Lac)
# count                      4894.000000            4894.000000
# mean                          5.395586              13.935635
# std                           1.705364               6.451959
# min                           3.000000               5.000000
# 25%                           4.000000               8.000000
# 50%                           5.000000              13.000000
# 75%                           7.000000              19.000000
# ...

# %%
df.dtypes
# Out:
# Name                                                                object
# Email ID                                                            object
# Quantity                                                             int64
# Events                                                              object
# Attendee Status                                                     object
# College Name                                                        object
# How did you come to know about this event?                          object
# Specify in "Others" (how did you come to know about this event)     object
# Designation                                                         object
# Year of Graduation                                                   int64
# City                                                                object
# CGPA                                                               float64
# ...

# %%
df.isnull().sum()
# Out:
# Name                                                                  0
# Email ID                                                              0
# Quantity                                                              0
# Events                                                                0
# Attendee Status                                                       0
# College Name                                                         15
# How did you come to know about this event?                         2216
# Specify in "Others" (how did you come to know about this event)    4805
# Designation                                                           0
# Year of Graduation                                                    0
# City                                                                  0
# CGPA                                                                  0
# Experience with python (Months)                                       0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4894 entries, 0 to 4893
# Data columns (total 16 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Name                                                             4894 non-null   object
#  1   Email ID                                                         4894 non-null   object
#  2   Quantity                                                         4894 non-null   int64
#  3   Events                                                           4894 non-null   object
#  4   Attendee Status                                                  4894 non-null   object
#  5   College Name                                                     4879 non-null   object
#  6   How did you come to know about this event?                       2678 non-null   object
# ...

# %%
df.nunique()
# Out:
# Name                                                               2324
# Email ID                                                           2157
# Quantity                                                              1
# Events                                                               16
# Attendee Status                                                       2
# College Name                                                         55
# How did you come to know about this event?                           99
# Specify in "Others" (how did you come to know about this event)      11
# Designation                                                          49
# Year of Graduation                                                    4
# City                                                                177
# CGPA                                                                 37
# Experience with python (Months)                                       6
# ...

# %%
print("Categories in 'Leadership-skills' variable:  ",end=" ")
print(df["Leadership- skills"].unique())

print("Categories in 'Attendee Status' variable:  ",end=" ")
print(df["Attendee Status"].unique())

print("Categories in 'Designation' variable:  ",end=" ")
print(df["Designation"].unique())

print("Categories in 'Events' variable:  ",end=" ")
print(df["Events"].unique())
# Out:
# Categories in 'Leadership-skills' variable:   ['yes' 'no' 'no ']
# Categories in 'Attendee Status' variable:   ['Attending' 'NAN']
# Categories in 'Designation' variable:   ['Students' 'Principal' 'Asst. Professor' 'HoD' 'Professor'
#  'Computer Engineer' 'Interior designer' 'CVO' 'Web Development'
#  'Data Science and Analyst' 'B.Tech' 'Engineering ' 'CEO' 'Intern'
#  'Artificial intelligence' 'Cyber Security' 'Software developer' 'CS'
#  'Administrative Officer ' 'IT' 'BE' 'Software Engineer' 'IT Engineering'
#  'Digital Marketing Intern' 'Computer applications' 'MBA Student'
#  'Recruitment Manager' 'BE CS'
#  'Executive Security Operations Center (SOC)' 'BE IT'
#  'Mechanical Engineer' 'Civil Engineering' 'Research Scholar'
#  'Key Account manager' 'B Sc IT' 'Graphic designer ' 'CSE' 'MTech'
#  'Founder' 'Sr. Manager' 'Flutter Developer' 'Electrical Engineering'
#  'Director T& P' 'MCA' 'Aerospace engineer ' 'SPC'
# ...

# %%
# Define a color palette for the countplot
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']
# blue, orange, green, red, purple are respectiively the color names for the color codes used above

# Create a figure with two subplots
f, ax = plt.subplots(1, 2, figsize=(12, 6))

# Create a countplot of the 'race/ethnicity' column and add labels to the bars
sns.countplot(x=df['Year of Graduation'], data=df, palette=colors, ax=ax[0], saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container, color='black', size=14)

# Set font size of x-axis and y-axis labels and tick labels
ax[0].set_xlabel('Year of Graduation', fontsize=14)
ax[0].set_ylabel('Count', fontsize=14)
ax[0].tick_params(labelsize=14)



# Display the plot
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 9)
plt.style.use('fivethirtyeight')
sns.histplot(df["Experience with python (Months)"], palette = 'Blues')
plt.title('Experience with python (Months)', fontweight = 30, fontsize = 20)
plt.xlabel('Months')
plt.ylabel('count')
plt.show()

# %%
df['Leadership- skills'].value_counts().plot.bar(title='Frequency Distribution of Leadership- skills',color=['red','blue'],figsize=(3,3))
# Out:
# <AxesSubplot:title={'center':'Frequency Distribution of Leadership- skills'}>

# %%
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.title('CGPA')
sns.barplot(x="Experience with python (Months)", y="Expected salary (Lac)", data=df)
# Out:
# <AxesSubplot:title={'center':'CGPA'}, xlabel='Experience with python (Months)', ylabel='Expected salary (Lac)'>

# %%
sns.countplot(x = df['CGPA'], data=df, hue = df['Family Income'], palette = 'pastel')
plt.show()

# %%
df['Designation'].value_counts().plot.bar(title='Designation',color=['red','blue'],figsize=(10,3))
# Out:
# <AxesSubplot:title={'center':'Designation'}>

# %%
df['City'].value_counts().plot.bar(title='Frequency Distribution of City',color=['red','blue'],figsize=(10,10))
# Out:
# <AxesSubplot:title={'center':'Frequency Distribution of City'}>
